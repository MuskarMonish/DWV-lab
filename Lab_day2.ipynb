# %%
import numpy as np
import pandas as pd

# %%
obj= pd.Series([4,7,-5,3])
obj
# Out:
# 0    4
# 1    7
# 2   -5
# 3    3
# dtype: int64

# %%
obj2 = pd.Series([4, 7, -5, 3], index=["d", "b", "a", "c"])
obj2
# Out:
# d    4
# b    7
# a   -5
# c    3
# dtype: int64

# %%
"b" in obj2
# Out:
# True

# %%
pd.isna(obj2)
# Out:
# d    False
# b    False
# a    False
# c    False
# dtype: bool

# %%
pd.notna(obj2)
# Out:
# d    True
# b    True
# a    True
# c    True
# dtype: bool

# %%
obj.index = ["Bob", "Steve", "Jeff", "Ryan"]
obj
# Out:
# Bob      4
# Steve    7
# Jeff    -5
# Ryan     3
# dtype: int64

# %%
data = {"state": ["Ohio", "Ohio", "Ohio", "Nevada", "Nevada", "Nevada"],
        "year": [2000, 2001, 2002, 2001, 2002, 2003],
        "pop": [1.5, 1.7, 3.6, 2.4, 2.9, 3.2]}
frame = pd.DataFrame(data)

# %%
frame
# Out:
#     state  year  pop
# 0    Ohio  2000  1.5
# 1    Ohio  2001  1.7
# 2    Ohio  2002  3.6
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9
# 5  Nevada  2003  3.2

# %%
frame.head(2)
# Out:
#   state  year  pop
# 0  Ohio  2000  1.5
# 1  Ohio  2001  1.7

# %%
frame.tail(3)
# Out:
#     state  year  pop
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9
# 5  Nevada  2003  3.2

# %%
frame = pd.DataFrame(np.arange(9).reshape((3, 3)),
                     index=["a", "c", "d"],
                     columns=["Ohio", "Texas", "California"])
frame
# Out:
#    Ohio  Texas  California
# a     0      1           2
# c     3      4           5
# d     6      7           8

# %%
states=["Texas","Utah","California"]
frame.reindex(columns=states)
# Out:
#    Texas  Utah  California
# a      1   NaN           2
# c      4   NaN           5
# d      7   NaN           8

# %%
frame.reindex(states,axis="columns")
# Out:
#    Texas  Utah  California
# a      1   NaN           2
# c      4   NaN           5
# d      7   NaN           8

# %%
frame.drop(columns=["Texas"])
# Out:
#    Ohio  California
# a     0           2
# c     3           5
# d     6           8

# %% [markdown]
# **FROM HERE ON:**

# %%
obj=pd.Series([4,5,-3,6])
obj
# Out:
# 0    4
# 1    5
# 2   -3
# 3    6
# dtype: int64

# %%
obj.index=['a','b','c','d']

# %% [markdown]
# exponential of the values

# %%
np.exp(obj)
# Out:
# a     54.598150
# b    148.413159
# c      0.049787
# d    403.428793
# dtype: float64

# %%
print("b" in obj)
print("e" in obj)
# Out:
# True
# False

# %%
s_dict={"Ohio":1000,"Toronto":2000,"Texas":3000,"California":4000}
obj2=pd.Series(s_dict)
obj2
# Out:
# Ohio          1000
# Toronto       2000
# Texas         3000
# California    4000
# dtype: int64

# %%
states=["Ohio","Texas","Oregon","California"]
obj3=pd.Series(s_dict,index=states)
obj3
# Out:
# Ohio          1000.0
# Texas         3000.0
# Oregon           NaN
# California    4000.0
# dtype: float64

# %%
print(pd.notna(obj3),"\n")
print(pd.isna(obj3))
# Out:
# Ohio           True
# Texas          True
# Oregon        False
# California     True
# dtype: bool
#
# Ohio          False
# Texas         False
# Oregon         True
# California    False
# dtype: bool

# %%
obj3.isna()
# Out:
# Ohio          False
# Texas         False
# Oregon         True
# California    False
# dtype: bool

# %%
obj2 + obj3
# Out:
# California    8000.0
# Ohio          2000.0
# Oregon           NaN
# Texas         6000.0
# Toronto          NaN
# dtype: float64

# %%
data = {"state": ["Ohio", "Ohio", "Ohio", "Nevada", "Nevada", "Nevada"],
        "year": [2000, 2001, 2002, 2001, 2002, 2003],
        "pop": [1.5, 1.7, 3.6, 2.4, 2.9, 3.2]}
frame = pd.DataFrame(data)
frame
# Out:
#     state  year  pop
# 0    Ohio  2000  1.5
# 1    Ohio  2001  1.7
# 2    Ohio  2002  3.6
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9
# 5  Nevada  2003  3.2

# %%
frame.head()
# Out:
#     state  year  pop
# 0    Ohio  2000  1.5
# 1    Ohio  2001  1.7
# 2    Ohio  2002  3.6
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9

# %%
frame.tail()
# Out:
#     state  year  pop
# 1    Ohio  2001  1.7
# 2    Ohio  2002  3.6
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9
# 5  Nevada  2003  3.2

# %%
pd.DataFrame(data, columns=["year", "state", "pop"])
# Out:
#    year   state  pop
# 0  2000    Ohio  1.5
# 1  2001    Ohio  1.7
# 2  2002    Ohio  3.6
# 3  2001  Nevada  2.4
# 4  2002  Nevada  2.9
# 5  2003  Nevada  3.2

# %%
frame2 = pd.DataFrame(data, columns=["year", "state", "pop", "debt"])
frame2
frame2.columns
# Out:
# Index(['year', 'state', 'pop', 'debt'], dtype='object')

# %%
frame2["state"]
frame2.year
# Out:
# 0    2000
# 1    2001
# 2    2002
# 3    2001
# 4    2002
# 5    2003
# Name: year, dtype: int64

# %%
frame2.loc[1]
# Out:
# year     2001
# state    Ohio
# pop       1.7
# debt      NaN
# Name: 1, dtype: object

# %%
frame2.iloc[2]
# Out:
# year     2002
# state    Ohio
# pop       3.6
# debt      NaN
# Name: 2, dtype: object

# %%
frame2["debt"] = np.arange(6.)
frame2
# Out:
#    year   state  pop  debt
# 0  2000    Ohio  1.5   0.0
# 1  2001    Ohio  1.7   1.0
# 2  2002    Ohio  3.6   2.0
# 3  2001  Nevada  2.4   3.0
# 4  2002  Nevada  2.9   4.0
# 5  2003  Nevada  3.2   5.0

# %%
del frame2["debt"]
frame2.columns
# Out:
# Index(['year', 'state', 'pop'], dtype='object')

# %%
populations = {"Ohio": {2000: 1.5, 2001: 1.7, 2002: 3.6},
               "Nevada": {2001: 2.4, 2002: 2.9}}
frame3=pd.DataFrame(populations)
frame3
# Out:
#       Ohio  Nevada
# 2000   1.5     NaN
# 2001   1.7     2.4
# 2002   3.6     2.9

# %%
frame3.T
# Out:
#         2000  2001  2002
# Ohio     1.5   1.7   3.6
# Nevada   NaN   2.4   2.9

# %%
frame3.index.name = "year"
frame3.columns.name = "state"
frame3
# Out:
# state  Ohio  Nevada
# year
# 2000    1.5     NaN
# 2001    1.7     2.4
# 2002    3.6     2.9

# %%
frame3.to_numpy()
# Out:
# array([[1.5, nan],
#        [1.7, 2.4],
#        [3.6, 2.9]])

# %%
frame3
frame3.columns
print("Ohio" in frame3.columns)
2003 in frame3.index
# Out:
# True
# False

# %%
obj3 = pd.Series(["blue", "purple", "yellow"], index=[0, 2, 3])
obj3.reindex(np.arange(6), method="ffill")
# Out:
# 0      blue
# 1      blue
# 2    purple
# 3    yellow
# 4    yellow
# 5    yellow
# dtype: object

# %%
data = pd.DataFrame(np.arange(16).reshape((4, 4)),
                    index=["Ohio", "Colorado", "Utah", "New York"],
                    columns=["one", "two", "three", "four"])

# %%
data.iloc[2]
# Out:
# one       8
# two       9
# three    10
# four     11
# Name: Utah, dtype: int64

# %%
data[:2]
# Out:
#           one  two  three  four
# Ohio        0    1      2     3
# Colorado    4    5      6     7

# %%
d1=data.iloc[:,:3]

# %%
d1
# Out:
#           one  two  three
# Ohio        0    1      2
# Colorado    4    5      6
# Utah        8    9     10
# New York   12   13     14

# %%
data.iloc[:,:3]
# Out:
#           one  two  three
# Ohio        0    1      2
# Colorado    4    5      6
# Utah        8    9     10
# New York   12   13     14

# %%
df1 = pd.DataFrame({"A": [1, 2]})
df2 = pd.DataFrame({"B": [3, 4]})
print(df1)
print(df2)
df1 + df2
# Out:
#    A
# 0  1
# 1  2
#    B
# 0  3
# 1  4
#     A   B
# 0 NaN NaN
# 1 NaN NaN

# %%
df1.add(df2, fill_value=0)
# Out:
#      A    B
# 0  1.0  3.0
# 1  2.0  4.0

# %%
df1.add(df2)
# Out:
#     A   B
# 0 NaN NaN
# 1 NaN NaN

# %%
df1.reindex(columns=df2.columns, fill_value=0)
# Out:
#    B
# 0  0
# 1  0

# %%
frame = pd.DataFrame(np.arange(12.).reshape((4, 3)),
                     columns=list("bde"),
                     index=["Utah", "Ohio", "Texas", "Oregon"])
series = frame.iloc[0]

# %%
frame
# Out:
#           b     d     e
# Utah    0.0   1.0   2.0
# Ohio    3.0   4.0   5.0
# Texas   6.0   7.0   8.0
# Oregon  9.0  10.0  11.0

# %%
series
# Out:
# b    0.0
# d    1.0
# e    2.0
# Name: Utah, dtype: float64

# %%
frame - series
# Out:
#           b    d    e
# Utah    0.0  0.0  0.0
# Ohio    3.0  3.0  3.0
# Texas   6.0  6.0  6.0
# Oregon  9.0  9.0  9.0

# %%
frame + series
# Out:
#           b     d     e
# Utah    0.0   2.0   4.0
# Ohio    3.0   5.0   7.0
# Texas   6.0   8.0  10.0
# Oregon  9.0  11.0  13.0

# %%
frame.sub(series)
# Out:
#           b    d    e
# Utah    0.0  0.0  0.0
# Ohio    3.0  3.0  3.0
# Texas   6.0  6.0  6.0
# Oregon  9.0  9.0  9.0

# %%
def f1(x):
    return x.max() - x.min()

frame.apply(f1)
# Out:
# b    9.0
# d    9.0
# e    9.0
# dtype: float64

# %%
def f2(x):
    return pd.Series([x.min(), x.max()], index=["min", "max"])
frame.apply(f2)
# Out:
#        b     d     e
# min  0.0   1.0   2.0
# max  9.0  10.0  11.0

# %%
def my_format(x):
    return f"{x:.2f}"

frame.applymap(my_format)
# Out:
#            b      d      e
# Utah    0.00   1.00   2.00
# Ohio    3.00   4.00   5.00
# Texas   6.00   7.00   8.00
# Oregon  9.00  10.00  11.00

# %%
frame["e"].map(my_format)
# Out:
# Utah       2.00
# Ohio       5.00
# Texas      8.00
# Oregon    11.00
# Name: e, dtype: object
