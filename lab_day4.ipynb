# %%
import pandas as pd

# %%
data=pd.read_csv("/content/Cars_Multi.csv")

# %%
data
# Out:
#       ID   mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0      1  18.0          8         307.0        130    3504          12.0
# 1      2  15.0          8         350.0        165    3693          11.5
# 2      3  18.0          8         318.0        150    3436          11.0
# 3      4  16.0          8         304.0        150    3433          12.0
# 4      5  17.0          8         302.0        140    3449          10.5
# ..   ...   ...        ...           ...        ...     ...           ...
# 393  394  27.0          4         140.0         86    2790          15.6
# 394  395  44.0          4          97.0         52    2130          24.6
# 395  396  32.0          4         135.0         84    2295          11.6
# 396  397  28.0          4         120.0         79    2625          18.6
# 397  398  31.0          4         119.0         82    2720          19.4
#
#      model  origin                   car_name
# ...

# %%
data.mpg
# Out:
# 0      18.0
# 1      15.0
# 2      18.0
# 3      16.0
# 4      17.0
#        ...
# 393    27.0
# 394    44.0
# 395    32.0
# 396    28.0
# 397    31.0
# Name: mpg, Length: 398, dtype: float64

# %%
data.columns
# Out:
# Index(['ID', 'mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model', 'origin', 'car_name'],
#       dtype='object')

# %%
data["mpg"]
# Out:
# 0      18.0
# 1      15.0
# 2      18.0
# 3      16.0
# 4      17.0
#        ...
# 393    27.0
# 394    44.0
# 395    32.0
# 396    28.0
# 397    31.0
# Name: mpg, Length: 398, dtype: float64

# %%
#STARTS HERE

# %%
df=pd.read_csv("/content/Cars_Multi.csv")

# %%
pd.read_table("/content/Cars_Multi.csv",sep=',')
# Out:
#       ID   mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0      1  18.0          8         307.0        130    3504          12.0
# 1      2  15.0          8         350.0        165    3693          11.5
# 2      3  18.0          8         318.0        150    3436          11.0
# 3      4  16.0          8         304.0        150    3433          12.0
# 4      5  17.0          8         302.0        140    3449          10.5
# ..   ...   ...        ...           ...        ...     ...           ...
# 393  394  27.0          4         140.0         86    2790          15.6
# 394  395  44.0          4          97.0         52    2130          24.6
# 395  396  32.0          4         135.0         84    2295          11.6
# 396  397  28.0          4         120.0         79    2625          18.6
# 397  398  31.0          4         119.0         82    2720          19.4
#
#      model  origin                   car_name
# ...

# %%
pd.read_csv("/content/Cars_Multi.csv",header=None).head(2)
# Out:
#     0    1          2             3           4       5             6      7  \
# 0  ID  mpg  cylinders  displacement  horsepower  weight  acceleration  model
# 1   1   18          8           307         130    3504            12     70
#
#         8                          9
# 0  origin                   car_name
# 1       1  chevrolet chevelle malibu

# %%
pd.read_csv('/content/Cars_Multi.csv',names=['a','b','c','d','e','f','g','h','i']).tail(2)
# Out:
#       a  b    c   d     e     f   g  h            i
# 397  28  4  120  79  2625  18.6  82  1  ford ranger
# 398  31  4  119  82  2720  19.4  82  1   chevy s-10

# %%
names=['a','b','c','d','e','f','g','h','i','MyID']
pd.read_csv("/content/Cars_Multi.csv",names=names,index_col='MyID').head(2)
# Out:
#                             a    b          c             d           e  \
# MyID
# car_name                   ID  mpg  cylinders  displacement  horsepower
# chevrolet chevelle malibu   1   18          8           307         130
#
#                                 f             g      h       i
# MyID
# car_name                   weight  acceleration  model  origin
# chevrolet chevelle malibu    3504            12     70       1

# %%
pd.read_csv('/content/Cars_Multi.csv',skiprows=[2,3,4]).head(2)
# Out:
#    ID   mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0   1  18.0          8         307.0        130    3504          12.0     70
# 1   5  17.0          8         302.0        140    3449          10.5     70
#
#    origin                   car_name
# 0       1  chevrolet chevelle malibu
# 1       1                ford torino

# %%
#Data with missing values
pd.isnull(df)
# Out:
#         ID    mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    False  False      False         False       False   False         False
# 1    False  False      False         False       False   False         False
# 2    False  False      False         False       False   False         False
# 3    False  False      False         False       False   False         False
# 4    False  False      False         False       False   False         False
# ..     ...    ...        ...           ...         ...     ...           ...
# 393  False  False      False         False       False   False         False
# 394  False  False      False         False       False   False         False
# 395  False  False      False         False       False   False         False
# 396  False  False      False         False       False   False         False
# 397  False  False      False         False       False   False         False
#
#      model  origin  car_name
# ...

# %%
#Reading small number of rows
pd.read_csv('/content/Cars_Multi.csv',nrows=3)
# Out:
#    ID  mpg  cylinders  displacement  horsepower  weight  acceleration  model  \
# 0   1   18          8           307         130    3504          12.0     70
# 1   2   15          8           350         165    3693          11.5     70
# 2   3   18          8           318         150    3436          11.0     70
#
#    origin                   car_name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite

# %%
chunker=pd.read_csv('/content/Cars_Multi.csv',chunksize=100)
tot=pd.Series([])
for piece in chunker:
  tot=tot.add(piece['mpg'].value_counts(),fill_value=0)
tot=tot.sort_values(ascending=False)
tot[:4]
# Out:
# <ipython-input-48-fbd0e3c28e2a>:2: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   tot=pd.Series([])
# 13    20.0
# 14    19.0
# 18    17.0
# 15    16.0
# dtype: float64

# %%
#DF to csv file
df.to_csv('sample1.csv')

# %%
# !cat sample1.csv
# Out:
# ,ID,mpg,cylinders,displacement,horsepower,weight,acceleration,model,origin,car_name
# 0,1,18.0,8,307.0,130,3504,12.0,70,1,chevrolet chevelle malibu
# 1,2,15.0,8,350.0,165,3693,11.5,70,1,buick skylark 320
# 2,3,18.0,8,318.0,150,3436,11.0,70,1,plymouth satellite
# 3,4,16.0,8,304.0,150,3433,12.0,70,1,amc rebel sst
# 4,5,17.0,8,302.0,140,3449,10.5,70,1,ford torino
# 5,6,15.0,8,429.0,198,4341,10.0,70,1,ford galaxie 500
# 6,7,14.0,8,454.0,220,4354,9.0,70,1,chevrolet impala
# 7,8,14.0,8,440.0,215,4312,8.5,70,1,plymouth fury iii
# 8,9,14.0,8,455.0,225,4425,10.0,70,1,pontiac catalina
# 9,10,15.0,8,390.0,190,3850,8.5,70,1,amc ambassador dpl
# 10,11,15.0,8,383.0,170,3563,10.0,70,1,dodge challenger se
# 11,12,14.0,8,340.0,160,3609,8.0,70,1,plymouth 'cuda 340
# 12,13,15.0,8,400.0,150,3761,9.5,70,1,chevrolet monte carlo
# 13,14,14.0,8,455.0,225,3086,10.0,70,1,buick estate wagon (sw)
# 14,15,24.0,4,113.0,95,2372,15.0,70,3,toyota corona mark ii
# 15,16,22.0,6,198.0,95,2833,15.5,70,1,plymouth duster
# ...

# %%
#Using delimiter and print result to the console
import sys

# %%
df.to_csv(sys.stdout,sep='|')
# Out:
# |ID|mpg|cylinders|displacement|horsepower|weight|acceleration|model|origin|car_name
# 0|1|18.0|8|307.0|130|3504|12.0|70|1|chevrolet chevelle malibu
# 1|2|15.0|8|350.0|165|3693|11.5|70|1|buick skylark 320
# 2|3|18.0|8|318.0|150|3436|11.0|70|1|plymouth satellite
# 3|4|16.0|8|304.0|150|3433|12.0|70|1|amc rebel sst
# 4|5|17.0|8|302.0|140|3449|10.5|70|1|ford torino
# 5|6|15.0|8|429.0|198|4341|10.0|70|1|ford galaxie 500
# 6|7|14.0|8|454.0|220|4354|9.0|70|1|chevrolet impala
# 7|8|14.0|8|440.0|215|4312|8.5|70|1|plymouth fury iii
# 8|9|14.0|8|455.0|225|4425|10.0|70|1|pontiac catalina
# 9|10|15.0|8|390.0|190|3850|8.5|70|1|amc ambassador dpl
# 10|11|15.0|8|383.0|170|3563|10.0|70|1|dodge challenger se
# 11|12|14.0|8|340.0|160|3609|8.0|70|1|plymouth 'cuda 340
# 12|13|15.0|8|400.0|150|3761|9.5|70|1|chevrolet monte carlo
# 13|14|14.0|8|455.0|225|3086|10.0|70|1|buick estate wagon (sw)
# 14|15|24.0|4|113.0|95|2372|15.0|70|3|toyota corona mark ii
# 15|16|22.0|6|198.0|95|2833|15.5|70|1|plymouth duster
# ...

# %%
#Denoting missing values by some string
df.to_csv(sys.stdout,na_rep='NU')
# Out:
# ,ID,mpg,cylinders,displacement,horsepower,weight,acceleration,model,origin,car_name
# 0,1,18.0,8,307.0,130,3504,12.0,70,1,chevrolet chevelle malibu
# 1,2,15.0,8,350.0,165,3693,11.5,70,1,buick skylark 320
# 2,3,18.0,8,318.0,150,3436,11.0,70,1,plymouth satellite
# 3,4,16.0,8,304.0,150,3433,12.0,70,1,amc rebel sst
# 4,5,17.0,8,302.0,140,3449,10.5,70,1,ford torino
# 5,6,15.0,8,429.0,198,4341,10.0,70,1,ford galaxie 500
# 6,7,14.0,8,454.0,220,4354,9.0,70,1,chevrolet impala
# 7,8,14.0,8,440.0,215,4312,8.5,70,1,plymouth fury iii
# 8,9,14.0,8,455.0,225,4425,10.0,70,1,pontiac catalina
# 9,10,15.0,8,390.0,190,3850,8.5,70,1,amc ambassador dpl
# 10,11,15.0,8,383.0,170,3563,10.0,70,1,dodge challenger se
# 11,12,14.0,8,340.0,160,3609,8.0,70,1,plymouth 'cuda 340
# 12,13,15.0,8,400.0,150,3761,9.5,70,1,chevrolet monte carlo
# 13,14,14.0,8,455.0,225,3086,10.0,70,1,buick estate wagon (sw)
# 14,15,24.0,4,113.0,95,2372,15.0,70,3,toyota corona mark ii
# 15,16,22.0,6,198.0,95,2833,15.5,70,1,plymouth duster
# ...

# %%
#with rows and column labels disabled
df.to_csv(sys.stdout,index=False,header=False)
# Out:
# 1,18.0,8,307.0,130,3504,12.0,70,1,chevrolet chevelle malibu
# 2,15.0,8,350.0,165,3693,11.5,70,1,buick skylark 320
# 3,18.0,8,318.0,150,3436,11.0,70,1,plymouth satellite
# 4,16.0,8,304.0,150,3433,12.0,70,1,amc rebel sst
# 5,17.0,8,302.0,140,3449,10.5,70,1,ford torino
# 6,15.0,8,429.0,198,4341,10.0,70,1,ford galaxie 500
# 7,14.0,8,454.0,220,4354,9.0,70,1,chevrolet impala
# 8,14.0,8,440.0,215,4312,8.5,70,1,plymouth fury iii
# 9,14.0,8,455.0,225,4425,10.0,70,1,pontiac catalina
# 10,15.0,8,390.0,190,3850,8.5,70,1,amc ambassador dpl
# 11,15.0,8,383.0,170,3563,10.0,70,1,dodge challenger se
# 12,14.0,8,340.0,160,3609,8.0,70,1,plymouth 'cuda 340
# 13,15.0,8,400.0,150,3761,9.5,70,1,chevrolet monte carlo
# 14,14.0,8,455.0,225,3086,10.0,70,1,buick estate wagon (sw)
# 15,24.0,4,113.0,95,2372,15.0,70,3,toyota corona mark ii
# 16,22.0,6,198.0,95,2833,15.5,70,1,plymouth duster
# 17,18.0,6,199.0,97,2774,15.5,70,1,amc hornet
# 18,21.0,6,200.0,85,2587,16.0,70,1,ford maverick
# ...

# %%
#subset of columns
df.to_csv(sys.stdout,index=False,columns=['ID','horsepower','mpg'])
# Out:
# ID,horsepower,mpg
# 1,130,18.0
# 2,165,15.0
# 3,150,18.0
# 4,150,16.0
# 5,140,17.0
# 6,198,15.0
# 7,220,14.0
# 8,215,14.0
# 9,225,14.0
# 10,190,15.0
# 11,170,15.0
# 12,160,14.0
# 13,150,15.0
# 14,225,14.0
# 15,95,24.0
# 16,95,22.0
# 17,97,18.0
# 18,85,21.0
# 19,88,27.0
# 20,46,26.0
# 21,87,25.0
# 22,90,24.0
# 23,95,25.0
# 24,113,26.0
# 25,90,21.0
# 26,215,10.0
# 27,200,10.0
# 28,210,11.0
# 29,193,9.0
# 30,88,27.0
# 31,90,28.0
# 32,95,25.0
# 33,?,25.0
# 34,100,19.0
# 35,105,16.0
# 36,100,17.0
# 37,88,19.0
# 38,100,18.0
# 39,165,14.0
# 40,175,14.0
# 41,153,14.0
# 42,150,14.0
# 43,180,12.0
# 44,170,13.0
# 45,175,13.0
# 46,110,18.0
# 47,72,22.0
# 48,100,19.0
# 49,88,18.0
# 50,86,23.0
# 51,90,28.0
# 52,70,30.0
# 53,76,30.0
# 54,65,31.0
# 55,69,35.0
# 56,60,27.0
# 57,70,26.0
# 58,95,24.0
# 59,80,25.0
# 60,54,23.0
# 61,90,20.0
# 62,86,21.0
# 63,165,13.0
# 64,175,14.0
# 65,150,15.0
# 66,153,14.0
# 67,150,17.0
# 68,208,11.0
# 69,155,13.0
# 70,160,12.0
# 71,190,13.0
# 72,97,19.0
# 73,150,15.0
# ...

# %%
import numpy as np

# %%
dates=pd.date_range('1/1/2023',periods=4)
ts=pd.Series(np.arange(4),index=dates)
ts.to_csv('sampleTime.csv')

# %%
pd.read_csv('/content/sampleTime.csv')
# Out:
#    Unnamed: 0  0
# 0  2023-01-01  0
# 1  2023-01-02  1
# 2  2023-01-03  2
# 3  2023-01-04  3

# %%
import csv
f = open('/content/Example1 - Sheet1.csv')
reader=csv.reader(f)

# %%
for line in reader:
  print(line)
# Out:
# ['a', 'b', 'c']
# ['1', '2', '3']
# ['4', '5', '6']

# %%
with open('/content/Example1 - Sheet1.csv') as f:
  lines=list(csv.reader(f))
print(lines)
# Out:
# [['a', 'b', 'c'], ['1', '2', '3'], ['4', '5', '6']]

# %%
header,values=lines[0],lines[1:]
data_dict={h:v for h,v in zip(header,zip(*values))}
data_dict
# Out:
# {'a': ('1', '4'), 'b': ('2', '5'), 'c': ('3', '6')}

# %%
obj= """
{"name": "Anya",
"visits": ["US","Spain","Japan"],
"pet": null,
"siblings": [{"name": "Scott","age": 20,"pets": ["Zeus","Zeku"]},
             {"name": "Sara","age": 18,"pets": ["Lee","Zee"]}]
}
"""

# %%
#json string to python object
import json
res=json.loads(obj)
res
# Out:
# {'name': 'Anya',
#  'visits': ['US', 'Spain', 'Japan'],
#  'pet': None,
#  'siblings': [{'name': 'Scott', 'age': 20, 'pets': ['Zeus', 'Zeku']},
#   {'name': 'Sara', 'age': 18, 'pets': ['Lee', 'Zee']}]}

# %%
#python obj to json
asjson=json.dumps(res)
asjson
# Out:
# '{"name": "Anya", "visits": ["US", "Spain", "Japan"], "pet": null, "siblings": [{"name": "Scott", "age": 20, "pets": ["Zeus", "Zeku"]}, {"name": "Sara", "age": 18, "pets": ["Lee", "Zee"]}]}'

# %%
#subset of data fields
siblings=pd.DataFrame(res['siblings'],columns=['name','age'])
siblings
# Out:
#     name  age
# 0  Scott   20
# 1   Sara   18

# %%
data=pd.read_json('/content/sample1.json')
data
# Out:
#    a  b  c
# 0  1  2  3
# 1  2  3  4

# %%
print(data.to_json())
print(data.to_json(orient='records'))
# Out:
# {"a":{"0":1,"1":2},"b":{"0":2,"1":3},"c":{"0":3,"1":4}}
# [{"a":1,"b":2,"c":3},{"a":2,"b":3,"c":4}]
