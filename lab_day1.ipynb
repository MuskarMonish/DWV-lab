# %%
import pandas as pd

# %%
obj=pd.Series(data=[4,1,3,-8])

# %%
print(obj)
# Out:
# 0    4
# 1    1
# 2    3
# 3   -8
# dtype: int64

# %%
obj.values
# Out:
# array([ 4,  1,  3, -8])

# %%
obj.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
obj2= pd.Series([4,1,3,-8],index=['d','b','a','c'])
obj2
# Out:
# d    4
# b    1
# a    3
# c   -8
# dtype: int64

# %%
obj2.values
# Out:
# array([ 4,  1,  3, -8])

# %%
obj2.index
# Out:
# Index(['d', 'b', 'a', 'c'], dtype='object')

# %%
obj2['a']
# Out:
# 3

# %%
obj2[obj2>0]
# Out:
# d    4
# b    1
# a    3
# dtype: int64

# %%
obj2[['b','c']]
# Out:
# b    1
# c   -8
# dtype: int64

# %%
obj2>0
# Out:
# d     True
# b     True
# a     True
# c    False
# dtype: bool

# %%
obj2*4
# Out:
# d    16
# b     4
# a    12
# c   -32
# dtype: int64

# %%
obj2['d':'c']
# Out:
# d    4
# b    1
# a    3
# c   -8
# dtype: int64

# %%
obj2.index=['a','b','c','d']
obj2
# Out:
# a    4
# b    1
# c    3
# d   -8
# dtype: int64

# %%
obj2['c']=-12
obj2
# Out:
# a     4
# b     1
# c   -12
# d    -8
# dtype: int64

# %%
obj2[['a','d']]=[2,3]
obj2
# Out:
# a     2
# b     1
# c   -12
# d     3
# dtype: int64

# %%
obj2[['a','b','d']]=10,20,30 #done
obj2
# Out:
# a    10
# b    20
# c   -12
# d    30
# dtype: int64

# %%
obj2['a','d']=40,50
obj2
# Out:
# a    40
# b    20
# c   -12
# d    50
# dtype: int64

# %%
obj2[1]
# Out:
# 20

# %%
import numpy as np
np.exp(obj2)
# Out:
# a    2.202647e+04
# b    4.851652e+08
# c    6.144212e-06
# d    1.068647e+13
# dtype: float64

# %%
dict={'yash':100,'sam':200}

# %%
s=pd.Series(dict)

# %%
print(s)
# Out:
# yash    100
# sam     200
# dtype: int64

# %%
s
# Out:
# yash    100
# sam     200
# dtype: int64

# %%
i=['yash','harsh','sam']

# %%
val=['100','0','200']

# %%
s3=pd.Series(dict,i)

# %%
s3
# Out:
# yash     100.0
# harsh      NaN
# sam      200.0
# dtype: float64

# %%
s2=pd.Series(val,index=i)

# %%
s2
# Out:
# yash     100
# harsh      0
# sam      200
# dtype: object

# %%
s3['harsh']=1

# %%
s3
# Out:
# yash     100.0
# harsh      1.0
# sam      200.0
# dtype: float64

# %%
s3['yash','sam']=[4,5]

# %%
s3
# Out:
# yash     4.0
# harsh    1.0
# sam      5.0
# dtype: float64

# %%
s3[s3==5]
# Out:
# sam    5.0
# dtype: float64

# %% [markdown]
# Multiply all the elements with 2

# %%
obj2
# Out:
# d    4
# b    1
# a    3
# c   -8
# dtype: int64

# %%
obj2*2
# Out:
# d     8
# b     2
# a     6
# c   -16
# dtype: int64

# %%
obj2[obj2>=3]
# Out:
# d    4
# a    3
# dtype: int64

# %%
obj2%2
# Out:
# d    0
# b    1
# a    1
# c    0
# dtype: int64

# %%
dict1={"Ohio":17000,"Oregon":18000,"Texas":19000,"California":20000}

# %%
s_dict1=pd.Series(dict1)

# %%
s_dict1
# Out:
# Ohio          17000
# Oregon        18000
# Texas         19000
# California    20000
# dtype: int64

# %%
s_dict1.index
# Out:
# Index(['Ohio', 'Oregon', 'Texas', 'California'], dtype='object')

# %%
s_dict1.values
# Out:
# array([17000, 18000, 19000, 20000])

# %%
s_dict1.index=["Atlanta","California","Texas","Oregon"]

# %%
s_dict1
# Out:
# Atlanta       17000
# California    18000
# Texas         19000
# Oregon        20000
# dtype: int64

# %%
n=pd.Series(1)

# %%
n
# Out:
# 0    1
# dtype: int64

# %%
type(n)
# Out:
# pandas.core.series.Series

# %%
type(dict1)
# Out:
# dict

# %%
type(dict1['Texas'])
# Out:
# int

# %%
s_dict1.name='population'

# %%
s_dict1
# Out:
# Atlanta       17000
# California    18000
# Texas         19000
# Oregon        20000
# Name: population, dtype: int64

# %%
s_dict1.index.name='State'

# %%
s_dict1
# Out:
# State
# Atlanta       17000
# California    18000
# Texas         19000
# Oregon        20000
# Name: population, dtype: int64

# %%
s2=pd.Series(12,index=[4,6,8])

# %%
print(s2)
# Out:
# 4    12
# 6    12
# 8    12
# dtype: int64

# %%
p=pd.Series(['a','e','i','o','u'],index=['a','e','i','o','u'])

# %%
p
# Out:
# a    a
# e    e
# i    i
# o    o
# u    u
# dtype: object

# %%
p.name="Vowels"

# %%
p.index.name="Vowels"

# %%
p
# Out:
# Vowels
# a    a
# e    e
# i    i
# o    o
# u    u
# Name: Vowels, dtype: object
